# %%
import pandas as pd

# %%
#conjunto de datos
datos= {
    "usuario": ["Ana","Luis","Martha","Carolina","Sofia","Pedro","Elena","Diego"],
    "edad": [22,33,28,40,19,31,26,45],
    "ciudad": ["CDMX","Monterrey","Guadalajara", "Puebla","Cancun", "Merida","Tijuana","toluca"],
    "compras_realizadas": [5,12,3,29,1,7,4,15],
    "activo": [True,False,True,True,False,True,True,False],
    "fecha_registro":["2026-02-10","2026-01-19","2026-02-19","2026-01-05","2026-02-03","2026-04-02","2026-09-12","2026-04-05"]
}

# %%
df=pd.DataFrame(datos)
df
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    22         CDMX                   5    True     2026-02-10
# 1      Luis    33    Monterrey                  12   False     2026-01-19
# 2    Martha    28  Guadalajara                   3    True     2026-02-19
# 3  Carolina    40       Puebla                  29    True     2026-01-05
# 4     Sofia    19       Cancun                   1   False     2026-02-03
# 5     Pedro    31       Merida                   7    True     2026-04-02
# 6     Elena    26      Tijuana                   4    True     2026-09-12
# 7     Diego    45       toluca                  15   False     2026-04-05

# %%
df.head()
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    22         CDMX                   5    True     2026-02-10
# 1      Luis    33    Monterrey                  12   False     2026-01-19
# 2    Martha    28  Guadalajara                   3    True     2026-02-19
# 3  Carolina    40       Puebla                  29    True     2026-01-05
# 4     Sofia    19       Cancun                   1   False     2026-02-03

# %%
cantidad= 100000

# %%
import random

# %%
nombres=  ["Ana","Luis","Martha","Carolina","Sofia","Pedro","Elena","Diego"]
ciudades = ["CDMX","Monterrey","Guadalajara", "Puebla","Cancun", "Merida","Tijuana","toluca"]
categorias = ["Tecnologia","Ropa","Hogar","Videojuegos","Deportes","Calzado","Limpieza","verano"]

# %%
dfMillon= pd.DataFrame({
    "nombre": [random.choice(nombres) for _ in range(cantidad) ],
    "edad": (random.randint(18,65) for _ in range(cantidad)),
    "ciudad": [random.choice(ciudades) for _ in range(cantidad)],
    "categoria": [random.choice(categorias) for _ in range(cantidad)],
})

# %%
df.memory_usage(deep=True)
# Out:
# Index                 132
# usuario               433
# edad                   64
# ciudad                447
# compras_realizadas     64
# activo                  8
# fecha_registro        472
# dtype: int64
