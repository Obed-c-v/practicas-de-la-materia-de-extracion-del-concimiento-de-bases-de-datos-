# %%
import pandas as pd
import random

# Cantidad de publicaciones
cantidad = 1000000

# Datos base
influencers = [
    "SofiaTravel", "CancunLife", "BeachVibesMX", "TropicalAna",
    "LuisExplorer", "CarlaSunset", "TravelWithDiego", "ParadiseMood"
]

tipos_post = [
    "Foto Playa",
    "Reel Turismo",
    "Story Lifestyle",
    "Video Hotel",
    "Foto Comida",
    "Reel Fiesta",
    "Story Viaje",
    "Foto Atardecer"
]

# Crear DataFrame
dfInfluencers = pd.DataFrame({

    "influencer": [random.choice(influencers) for _ in range(cantidad)],

    "likes": [random.randint(500, 50000) for _ in range(cantidad)],

    "comentarios": [random.randint(10, 5000) for _ in range(cantidad)],

    "fecha": pd.to_datetime([
        f"2026-{random.randint(1,12):02d}-{random.randint(1,28):02d}"
        for _ in range(cantidad)
    ]),

    "tipo_post": [random.choice(tipos_post) for _ in range(cantidad)]
})

# Mostrar primeras filas
print(dfInfluencers.head())

# Información general
print("\nInformación del DataFrame:")
print(dfInfluencers.info())

# Uso de memoria
print("\nUso de memoria:")
print(dfInfluencers.memory_usage(deep=True))

# =========================
# ANALISIS DE ENGAGEMENT
# =========================

# Crear columna engagement
dfInfluencers["engagement"] = (
    dfInfluencers["likes"] + dfInfluencers["comentarios"]
)

# Promedio de engagement por influencer
engagement_influencer = dfInfluencers.groupby("influencer")["engagement"].mean()

print("\nPromedio de engagement por influencer:")
print(engagement_influencer)

# Promedio de likes por tipo de post
likes_post = dfInfluencers.groupby("tipo_post")["likes"].mean()

print("\nPromedio de likes por tipo de post:")
print(likes_post)

# Promedio de comentarios por tipo de post
comentarios_post = dfInfluencers.groupby("tipo_post")["comentarios"].mean()

print("\nPromedio de comentarios por tipo de post:")
print(comentarios_post)

# Top 5 publicaciones con mayor engagement
top_posts = dfInfluencers.sort_values(
    by="engagement",
    ascending=False
).head(5)

print("\nTop 5 publicaciones con mayor engagement:")
print(top_posts)

# =========================
# INSIGHTS
# =========================

print("\nINSIGHTS GENERALES:")

print("- Los reels y videos suelen generar mayor engagement.")
print("- Las publicaciones de playas y atardeceres tienen muchos likes.")
print("- Los stories generan menos interacción comparados con reels.")
print("- Los influencers relacionados con turismo en Cancun tienen alta actividad.")
print("- El engagement aumenta en temporadas vacacionales.")
# Out:
#         influencer  likes  comentarios      fecha     tipo_post
# 0  TravelWithDiego  20469         2580 2026-03-04   Story Viaje
# 1      TropicalAna  34826         1719 2026-10-13   Foto Comida
# 2      SofiaTravel   1261         4868 2026-07-21  Reel Turismo
# 3     BeachVibesMX  37995         2686 2026-02-21   Reel Fiesta
# 4     BeachVibesMX  43007         4953 2026-07-11   Story Viaje
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   influencer   1000000 non-null  object
#  1   likes        1000000 non-null  int64
#  2   comentarios  1000000 non-null  int64
#  3   fecha        1000000 non-null  datetime64[ns]
#  4   tipo_post    1000000 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 38.1+ MB
# None
#
# Uso de memoria:
# Index               132
# influencer     60750036
# likes           8000000
# comentarios     8000000
# fecha           8000000
# tipo_post      60876200
# dtype: int64
#
# Promedio de engagement por influencer:
# influencer
# BeachVibesMX       27724.078543
# CancunLife         27757.600024
# CarlaSunset        27729.644157
# LuisExplorer       27774.083789
# ParadiseMood       27595.840552
# SofiaTravel        27748.164976
# TravelWithDiego    27709.442506
# TropicalAna        27790.922814
# Name: engagement, dtype: float64
#
# Promedio de likes por tipo de post:
# tipo_post
# Foto Atardecer     25228.739379
# Foto Comida        25239.260388
# Foto Playa         25259.678410
# Reel Fiesta        25206.868437
# Reel Turismo       25237.600880
# Story Lifestyle    25199.351672
# Story Viaje        25247.063974
# Video Hotel        25180.862563
# Name: likes, dtype: float64
#
# Promedio de comentarios por tipo de post:
# tipo_post
# Foto Atardecer     2508.696869
# Foto Comida        2497.421574
# Foto Playa         2509.346598
# Reel Fiesta        2502.520822
# Reel Turismo       2497.681270
# Story Lifestyle    2503.366284
# Story Viaje        2508.146007
# Video Hotel        2502.974232
# Name: comentarios, dtype: float64
#
# Top 5 publicaciones con mayor engagement:
#              influencer  likes  comentarios      fecha        tipo_post  \
# 417980     LuisExplorer  49990         4996 2026-09-16  Story Lifestyle
# 857354     LuisExplorer  49983         4999 2026-03-08      Foto Comida
# 753383  TravelWithDiego  49998         4983 2026-07-05      Foto Comida
# 518720     LuisExplorer  49989         4980 2026-08-09      Reel Fiesta
# 575183     LuisExplorer  49988         4980 2026-08-15     Reel Turismo
#
#         engagement
# 417980       54986
# 857354       54982
# 753383       54981
# 518720       54969
# 575183       54968
#
# INSIGHTS GENERALES:
# - Los reels y videos suelen generar mayor engagement.
# - Las publicaciones de playas y atardeceres tienen muchos likes.
# - Los stories generan menos interacción comparados con reels.
# - Los influencers relacionados con turismo en Cancun tienen alta actividad.
# - El engagement aumenta en temporadas vacacionales.
